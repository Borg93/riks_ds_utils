# %%
from glob import glob
import os
from pathlib import Path
from pathlib import PurePath
import cv2
from riks_ds_utils.page_transforms import PageTransforms
import numpy as np
import multiprocessing
from multiprocessing import Pool
import shutil
import json
import random

# %%
basepath = '/media/erik/Elements/Riksarkivet/data/datasets/htr/segmentation/police_records'

imgs = glob(os.path.join(basepath, '**', 'bin_image', '**'), recursive=True)
page = glob(os.path.join(basepath, '**', 'page', '**'), recursive=True)
imgs = [x for x in imgs if os.path.isfile(x)]
page = [x for x in page if os.path.isfile(x)]

imgs.sort()
page.sort()

assert len(imgs) == len(page)

print(len(imgs))

"""
imgs_checked = glob(os.path.join('/media/erik/Elements/Riksarkivet/data/datasets/htr/segmentation/ICDAR-2019/fiftyone/data', '**'))
imgs_checked = [Path(x).name for x in imgs_checked]

imgs_page = list(zip(imgs, page))

print(len(imgs_page))

imgs_page = [(x, y) for (x, y) in imgs_page if Path(x).name in imgs_checked]

print(len(imgs_page))

imgs = [x for (x, y) in imgs_page]
page = [y for (x, y) in imgs_page]

"""

PageTransforms.crop_text_reg_write_text_line_coco(
    page, 
    imgs, 
    '/media/erik/Elements/Riksarkivet/data/datasets/htr/segmentation/police_records',
    '/media/erik/Elements/Riksarkivet/data/datasets/htr/segmentation/police_records/gt_files/coco_lines2.json')
# Out:
# 6913
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900

# %%
l = [[0,1], [1,2], [3,4]]

x_offset = 0
y_offset = 0

l = [[x + x_offset, y + y_offset] for [x, y] in l]
l
